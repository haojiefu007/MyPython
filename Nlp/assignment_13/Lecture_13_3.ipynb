# %%
import torch
import torch.nn.functional as F
from transformers import GPT2Tokenizer, GPT2LMHeadModel, GPT2Config
from torch.utils.data import DataLoader,Dataset
from torch.nn.utils.rnn import pad_sequence
from torch.optim import Adam
from tqdm import tqdm
from torch.nn import CrossEntropyLoss

# %%
ls
# Out:
# Assigment_13_评阅点.html      Lecture_13_2.ipynb
# Assigment_13_评阅点.ipynb     Lecture_13_3.ipynb
# Assignment_13.ipynb           test.txt
# Lecture_13_1.ipynb

# %%
data_path = '../Data_source/'

# %%
train_data = 'test.txt'

# %%
def read_data(file):
    with open(file,'r',encoding='utf8') as data:
        lines = [l.strip() for l in data]
    dials = []
    for l in lines:
        if l == '<dial>':
            dial = []
        elif l == '</dial>':
            dials += [dial]
        else:
            dial += [l.strip()]
    return dials

# %%
dials = read_data(train_data)

# %%
dials
# Out:
# [['Good afternoon , madam . How can I help you ?',
#   "Well , I am a bit out of shape . I'm thinking about getting some exercises to keep fit .",
#   "Oh , that's good news for us .",
#   'So what do you provide ?',
#   "First of all , we'll design a custom-made work-out plan according to your habits .",
#   'How can you get that done ?',
#   'Well , we give each of our customers a personal trainer who is qualified . And he will give you a fitness assessment and then come up with the work-out plan for your needs .',
#   'What else ?',
#   'Since everyone is different , your personal trainer will find you a suitable type of exercise equipment and teach you all the techniques to help you achieve your fitness level and goal .',
#   'Sounds pretty good . What about the charge ?',
#   'That depends . We offer membership for one month , half a year and one year .'],
#  ['Good afternoon , madam . How can I help you ?',
#   "Well , I am a bit out of shape . I'm thinking about getting some exercises to keep fit .",
#   "Oh , that's good news for us .",
#   'So what do you provide ?',
#   "First of all , we'll design a custom-made work-out plan according to your habits .",
#   'How can you get that done ?',
#   'Well , we give each of our customers a personal trainer who is qualified . And he will give you a fitness assessment and then come up with the work-out plan for your needs .',
#   'What else ?',
#   'Since everyone is different , your personal trainer will find you a suitable type of exercise equipment and teach you all the techniques to help you achieve your fitness level and goal .',
#   'Sounds pretty good . What about the charge ?',
#   'That depends . We offer membership for one month , half a year and one year .',
#   'Maybe one month . Just have a try first . Not too tough at the beginning .'],
#  ['Good afternoon , madam . How can I help you ?',
#   "Well , I am a bit out of shape . I'm thinking about getting some exercises to keep fit .",
#   "Oh , that's good news for us .",
#   'So what do you provide ?',
#   "First of all , we'll design a custom-made work-out plan according to your habits .",
#   'How can you get that done ?',
#   'Well , we give each of our customers a personal trainer who is qualified . And he will give you a fitness assessment and then come up with the work-out plan for your needs .',
#   'What else ?',
#   'Since everyone is different , your personal trainer will find you a suitable type of exercise equipment and teach you all the techniques to help you achieve your fitness level and goal .',
#   'Sounds pretty good . What about the charge ?',
#   'That depends . We offer membership for one month , half a year and one year .',
#   'Maybe one month . Just have a try first . Not too tough at the beginning .',
#   "Wise decision . You'll find it's totally worth it ."],
#  ['Do you watch a lot of TV ?', 'Not really . I could take it or leave it .'],
#  ['Do you watch a lot of TV ?',
#   'Not really . I could take it or leave it .',
#   'Not me . I have to have my TV and watch whatever comes on .'],
#  ['Do you watch a lot of TV ?',
#   'Not really . I could take it or leave it .',
#   'Not me . I have to have my TV and watch whatever comes on .',
#   'How can you do that ?'],
#  ["Hi . What's your name ?", "My name is Jung Min . What's your name ?"],
#  ["Hi . What's your name ?",
#   "My name is Jung Min . What's your name ?",
#   "My name is Jessica . It's nice to meet you ."],
#  ["Hi . What's your name ?",
#   "My name is Jung Min . What's your name ?",
#   "My name is Jessica . It's nice to meet you .",
#   "Yes . It's nice to meet you too . Are you a new student too ?"],
#  ["Hi . What's your name ?",
#   "My name is Jung Min . What's your name ?",
#   "My name is Jessica . It's nice to meet you .",
#   "Yes . It's nice to meet you too . Are you a new student too ?",
#   "No . I'm a sophomore . I take it you are a new student ?"],
#  ["Hi . What's your name ?",
#   "My name is Jung Min . What's your name ?",
#   "My name is Jessica . It's nice to meet you .",
#   "Yes . It's nice to meet you too . Are you a new student too ?",
#   "No . I'm a sophomore . I take it you are a new student ?",
#   "Yeah . It's pretty exciting to be here ."],
#  ["Hi . What's your name ?",
#   "My name is Jung Min . What's your name ?",
#   "My name is Jessica . It's nice to meet you .",
#   "Yes . It's nice to meet you too . Are you a new student too ?",
#   "No . I'm a sophomore . I take it you are a new student ?",
#   "Yeah . It's pretty exciting to be here .",
#   'Have fun while it lasts . The excitement wears off real quick . Especially after you see how much homework you get . Where are you from ?'],
#  ["Hi . What's your name ?",
#   "My name is Jung Min . What's your name ?",
#   "My name is Jessica . It's nice to meet you .",
#   "Yes . It's nice to meet you too . Are you a new student too ?",
#   "No . I'm a sophomore . I take it you are a new student ?",
#   "Yeah . It's pretty exciting to be here .",
#   'Have fun while it lasts . The excitement wears off real quick . Especially after you see how much homework you get . Where are you from ?',
#   "I'm from Korea . My parents wanted me to go to an American university , so I came here ."],
#  ["Hi . What's your name ?",
#   "My name is Jung Min . What's your name ?",
#   "My name is Jessica . It's nice to meet you .",
#   "Yes . It's nice to meet you too . Are you a new student too ?",
#   "No . I'm a sophomore . I take it you are a new student ?",
#   "Yeah . It's pretty exciting to be here .",
#   'Have fun while it lasts . The excitement wears off real quick . Especially after you see how much homework you get . Where are you from ?',
#   "I'm from Korea . My parents wanted me to go to an American university , so I came here .",
#   "I have never been to Korea . I've been to Japan before , but never Korea ."],
#  ["Hi . What's your name ?",
#   "My name is Jung Min . What's your name ?",
#   "My name is Jessica . It's nice to meet you .",
#   "Yes . It's nice to meet you too . Are you a new student too ?",
#   "No . I'm a sophomore . I take it you are a new student ?",
#   "Yeah . It's pretty exciting to be here .",
#   'Have fun while it lasts . The excitement wears off real quick . Especially after you see how much homework you get . Where are you from ?',
#   "I'm from Korea . My parents wanted me to go to an American university , so I came here .",
#   "I have never been to Korea . I've been to Japan before , but never Korea .",
#   'Why were you in Japan ?'],
#  ["Hi . What's your name ?",
#   "My name is Jung Min . What's your name ?",
#   "My name is Jessica . It's nice to meet you .",
#   "Yes . It's nice to meet you too . Are you a new student too ?",
#   "No . I'm a sophomore . I take it you are a new student ?",
#   "Yeah . It's pretty exciting to be here .",
#   'Have fun while it lasts . The excitement wears off real quick . Especially after you see how much homework you get . Where are you from ?',
#   "I'm from Korea . My parents wanted me to go to an American university , so I came here .",
#   "I have never been to Korea . I've been to Japan before , but never Korea .",
#   'Why were you in Japan ?',
#   "My father thought it would be a good experience to take a vacation to a different country . He's so into learning about different cultures ."],
#  ["Hi . What's your name ?",
#   "My name is Jung Min . What's your name ?",
#   "My name is Jessica . It's nice to meet you .",
#   "Yes . It's nice to meet you too . Are you a new student too ?",
#   "No . I'm a sophomore . I take it you are a new student ?",
#   "Yeah . It's pretty exciting to be here .",
#   'Have fun while it lasts . The excitement wears off real quick . Especially after you see how much homework you get . Where are you from ?',
#   "I'm from Korea . My parents wanted me to go to an American university , so I came here .",
#   "I have never been to Korea . I've been to Japan before , but never Korea .",
#   'Why were you in Japan ?',
#   "My father thought it would be a good experience to take a vacation to a different country . He's so into learning about different cultures .",
#   "That's pretty cool ."],
#  ["Hi . What's your name ?",
#   "My name is Jung Min . What's your name ?",
#   "My name is Jessica . It's nice to meet you .",
#   "Yes . It's nice to meet you too . Are you a new student too ?",
#   "No . I'm a sophomore . I take it you are a new student ?",
#   "Yeah . It's pretty exciting to be here .",
#   'Have fun while it lasts . The excitement wears off real quick . Especially after you see how much homework you get . Where are you from ?',
#   "I'm from Korea . My parents wanted me to go to an American university , so I came here .",
#   "I have never been to Korea . I've been to Japan before , but never Korea .",
#   'Why were you in Japan ?',
#   "My father thought it would be a good experience to take a vacation to a different country . He's so into learning about different cultures .",
#   "That's pretty cool .",
#   'I thought it would have been more fun if I went without my parents .'],
#  ["Hi . What's your name ?",
#   "My name is Jung Min . What's your name ?",
#   "My name is Jessica . It's nice to meet you .",
#   "Yes . It's nice to meet you too . Are you a new student too ?",
#   "No . I'm a sophomore . I take it you are a new student ?",
#   "Yeah . It's pretty exciting to be here .",
#   'Have fun while it lasts . The excitement wears off real quick . Especially after you see how much homework you get . Where are you from ?',
#   "I'm from Korea . My parents wanted me to go to an American university , so I came here .",
#   "I have never been to Korea . I've been to Japan before , but never Korea .",
#   'Why were you in Japan ?',
#   "My father thought it would be a good experience to take a vacation to a different country . He's so into learning about different cultures .",
#   "That's pretty cool .",
#   'I thought it would have been more fun if I went without my parents .',
#   'Well , if you ever want to visit Korea , I would be happy to show you around .'],
#  ["Hi . What's your name ?",
#   "My name is Jung Min . What's your name ?",
#   "My name is Jessica . It's nice to meet you .",
#   "Yes . It's nice to meet you too . Are you a new student too ?",
#   "No . I'm a sophomore . I take it you are a new student ?",
#   "Yeah . It's pretty exciting to be here .",
#   'Have fun while it lasts . The excitement wears off real quick . Especially after you see how much homework you get . Where are you from ?',
#   "I'm from Korea . My parents wanted me to go to an American university , so I came here .",
#   "I have never been to Korea . I've been to Japan before , but never Korea .",
#   'Why were you in Japan ?',
#   "My father thought it would be a good experience to take a vacation to a different country . He's so into learning about different cultures .",
#   "That's pretty cool .",
#   'I thought it would have been more fun if I went without my parents .',
#   'Well , if you ever want to visit Korea , I would be happy to show you around .',
#   "Thanks for the offer . I'll keep that in mind . Oh , the professor is coming . We'll talk more after class ."],
#  ["Hi . What's your name ?",
#   "My name is Jung Min . What's your name ?",
#   "My name is Jessica . It's nice to meet you .",
#   "Yes . It's nice to meet you too . Are you a new student too ?",
#   "No . I'm a sophomore . I take it you are a new student ?",
#   "Yeah . It's pretty exciting to be here .",
#   'Have fun while it lasts . The excitement wears off real quick . Especially after you see how much homework you get . Where are you from ?',
#   "I'm from Korea . My parents wanted me to go to an American university , so I came here .",
#   "I have never been to Korea . I've been to Japan before , but never Korea .",
#   'Why were you in Japan ?',
#   "My father thought it would be a good experience to take a vacation to a different country . He's so into learning about different cultures .",
#   "That's pretty cool .",
#   'I thought it would have been more fun if I went without my parents .',
#   'Well , if you ever want to visit Korea , I would be happy to show you around .',
#   "Thanks for the offer . I'll keep that in mind . Oh , the professor is coming . We'll talk more after class .",
#   'Ok .'],
#  ['Guess who I saw just now ?', 'Who ?'],
#  ['Guess who I saw just now ?',
#   'Who ?',
#   'John Smith , the escaped criminal .'],
#  ['Guess who I saw just now ?',
#   'Who ?',
#   'John Smith , the escaped criminal .',
#   'That bad egg , who took the low road since he was a boy .'],
#  ['Guess who I saw just now ?',
#   'Who ?',
#   'John Smith , the escaped criminal .',
#   'That bad egg , who took the low road since he was a boy .',
#   'I think I must report to the cops .'],
#  ['Guess who I saw just now ?',
#   'Who ?',
#   'John Smith , the escaped criminal .',
#   'That bad egg , who took the low road since he was a boy .',
#   'I think I must report to the cops .',
#   'Ok .'],
#  ['What do you think of this one ?', 'Eh , so so .'],
#  ['What do you think of this one ?',
#   'Eh , so so .',
#   'And this one ? Too flashy ?'],
#  ['What do you think of this one ?',
#   'Eh , so so .',
#   'And this one ? Too flashy ?',
#   'Nah , not too flashy .'],
#  ['What do you think of this one ?',
#   'Eh , so so .',
#   'And this one ? Too flashy ?',
#   'Nah , not too flashy .',
#   'Hug ! And this sweater from my aunt ? Isn ’ t it hideous ?'],
#  ['What do you think of this one ?',
#   'Eh , so so .',
#   'And this one ? Too flashy ?',
#   'Nah , not too flashy .',
#   'Hug ! And this sweater from my aunt ? Isn ’ t it hideous ?',
#   'I guess .'],
#  ['What do you think of this one ?',
#   'Eh , so so .',
#   'And this one ? Too flashy ?',
#   'Nah , not too flashy .',
#   'Hug ! And this sweater from my aunt ? Isn ’ t it hideous ?',
#   'I guess .',
#   'Are you even listening ? I ’ m trying to have a conversation with you .'],
#  ['What do you think of this one ?',
#   'Eh , so so .',
#   'And this one ? Too flashy ?',
#   'Nah , not too flashy .',
#   'Hug ! And this sweater from my aunt ? Isn ’ t it hideous ?',
#   'I guess .',
#   'Are you even listening ? I ’ m trying to have a conversation with you .',
#   'And I ’ m trying to watch the game , but you ’ re yapping on about your new clothes !'],
#  ['What do you think of this one ?',
#   'Eh , so so .',
#   'And this one ? Too flashy ?',
#   'Nah , not too flashy .',
#   'Hug ! And this sweater from my aunt ? Isn ’ t it hideous ?',
#   'I guess .',
#   'Are you even listening ? I ’ m trying to have a conversation with you .',
#   'And I ’ m trying to watch the game , but you ’ re yapping on about your new clothes !',
#   'Well I have to decide which gifts to keep and which to exchange for better ones when I go to the Boxing Day sales this afternoon !'],
#  ['What do you think of this one ?',
#   'Eh , so so .',
#   'And this one ? Too flashy ?',
#   'Nah , not too flashy .',
#   'Hug ! And this sweater from my aunt ? Isn ’ t it hideous ?',
#   'I guess .',
#   'Are you even listening ? I ’ m trying to have a conversation with you .',
#   'And I ’ m trying to watch the game , but you ’ re yapping on about your new clothes !',
#   'Well I have to decide which gifts to keep and which to exchange for better ones when I go to the Boxing Day sales this afternoon !',
#   'Well could you do me the favor of making this quick ? It ’ s the third quarter and you ’ Ve been blabbering on since the first !'],
#  ['What do you think of this one ?',
#   'Eh , so so .',
#   'And this one ? Too flashy ?',
#   'Nah , not too flashy .',
#   'Hug ! And this sweater from my aunt ? Isn ’ t it hideous ?',
#   'I guess .',
#   'Are you even listening ? I ’ m trying to have a conversation with you .',
#   'And I ’ m trying to watch the game , but you ’ re yapping on about your new clothes !',
#   'Well I have to decide which gifts to keep and which to exchange for better ones when I go to the Boxing Day sales this afternoon !',
#   'Well could you do me the favor of making this quick ? It ’ s the third quarter and you ’ Ve been blabbering on since the first !',
#   'Oh , your precious game . You watch the same game every year , and each year your beloved hometown team loses by at least three goals !'],
#  ['What do you think of this one ?',
#   'Eh , so so .',
#   'And this one ? Too flashy ?',
#   'Nah , not too flashy .',
#   'Hug ! And this sweater from my aunt ? Isn ’ t it hideous ?',
#   'I guess .',
#   'Are you even listening ? I ’ m trying to have a conversation with you .',
#   'And I ’ m trying to watch the game , but you ’ re yapping on about your new clothes !',
#   'Well I have to decide which gifts to keep and which to exchange for better ones when I go to the Boxing Day sales this afternoon !',
#   'Well could you do me the favor of making this quick ? It ’ s the third quarter and you ’ Ve been blabbering on since the first !',
#   'Oh , your precious game . You watch the same game every year , and each year your beloved hometown team loses by at least three goals !',
#   'Oh no you didn ’ t . You didn ’ t just insult the Sals-bury Seals , did you ? Why don ’ t you just . just go and return all of those stupid clothes and not come back until the sales are over ?'],
#  ['What do you think of this one ?',
#   'Eh , so so .',
#   'And this one ? Too flashy ?',
#   'Nah , not too flashy .',
#   'Hug ! And this sweater from my aunt ? Isn ’ t it hideous ?',
#   'I guess .',
#   'Are you even listening ? I ’ m trying to have a conversation with you .',
#   'And I ’ m trying to watch the game , but you ’ re yapping on about your new clothes !',
#   'Well I have to decide which gifts to keep and which to exchange for better ones when I go to the Boxing Day sales this afternoon !',
#   'Well could you do me the favor of making this quick ? It ’ s the third quarter and you ’ Ve been blabbering on since the first !',
#   'Oh , your precious game . You watch the same game every year , and each year your beloved hometown team loses by at least three goals !',
#   'Oh no you didn ’ t . You didn ’ t just insult the Sals-bury Seals , did you ? Why don ’ t you just . just go and return all of those stupid clothes and not come back until the sales are over ?',
#   'I might just ! Enjoy your stupid game !'],
#  ['Hello . Nice to see you again . I heard you went into hospital for a few days to undergo surgery . I hope everything ’ s OK .',
#   'Yes , fine . I had something wrong with my stomach . I won ’ t go into detail , but it wasn ’ t serious .'],
#  ['Hello . Nice to see you again . I heard you went into hospital for a few days to undergo surgery . I hope everything ’ s OK .',
#   'Yes , fine . I had something wrong with my stomach . I won ’ t go into detail , but it wasn ’ t serious .',
#   'I really dislike going to a doctor or to a hospital .'],
#  ['Hello . Nice to see you again . I heard you went into hospital for a few days to undergo surgery . I hope everything ’ s OK .',
#   'Yes , fine . I had something wrong with my stomach . I won ’ t go into detail , but it wasn ’ t serious .',
#   'I really dislike going to a doctor or to a hospital .',
#   'I think most people are a little nervous about it . I was really very , very nervous just before I had the operation , but the anaesthetist gave me an anaesthetic and the next thing I remember was waking up after the operation .'],
#  ['Hello . Nice to see you again . I heard you went into hospital for a few days to undergo surgery . I hope everything ’ s OK .',
#   'Yes , fine . I had something wrong with my stomach . I won ’ t go into detail , but it wasn ’ t serious .',
#   'I really dislike going to a doctor or to a hospital .',
#   'I think most people are a little nervous about it . I was really very , very nervous just before I had the operation , but the anaesthetist gave me an anaesthetic and the next thing I remember was waking up after the operation .',
#   'It must have really hurt afterwards .'],
#  ['Hello . Nice to see you again . I heard you went into hospital for a few days to undergo surgery . I hope everything ’ s OK .',
#   'Yes , fine . I had something wrong with my stomach . I won ’ t go into detail , but it wasn ’ t serious .',
#   'I really dislike going to a doctor or to a hospital .',
#   'I think most people are a little nervous about it . I was really very , very nervous just before I had the operation , but the anaesthetist gave me an anaesthetic and the next thing I remember was waking up after the operation .',
#   'It must have really hurt afterwards .',
#   'Well , the nurse game me plenty of painkillers , but it did feel uncomfortable . I wasn ’ t permitted to eat anything for 48 hours . That was the worse thing .'],
#  ['Hello . Nice to see you again . I heard you went into hospital for a few days to undergo surgery . I hope everything ’ s OK .',
#   'Yes , fine . I had something wrong with my stomach . I won ’ t go into detail , but it wasn ’ t serious .',
#   'I really dislike going to a doctor or to a hospital .',
#   'I think most people are a little nervous about it . I was really very , very nervous just before I had the operation , but the anaesthetist gave me an anaesthetic and the next thing I remember was waking up after the operation .',
#   'It must have really hurt afterwards .',
#   'Well , the nurse game me plenty of painkillers , but it did feel uncomfortable . I wasn ’ t permitted to eat anything for 48 hours . That was the worse thing .',
#   'I bet you were ready for a thick juicy steak when you got out of hospital .'],
#  ['Hello . Nice to see you again . I heard you went into hospital for a few days to undergo surgery . I hope everything ’ s OK .',
#   'Yes , fine . I had something wrong with my stomach . I won ’ t go into detail , but it wasn ’ t serious .',
#   'I really dislike going to a doctor or to a hospital .',
#   'I think most people are a little nervous about it . I was really very , very nervous just before I had the operation , but the anaesthetist gave me an anaesthetic and the next thing I remember was waking up after the operation .',
#   'It must have really hurt afterwards .',
#   'Well , the nurse game me plenty of painkillers , but it did feel uncomfortable . I wasn ’ t permitted to eat anything for 48 hours . That was the worse thing .',
#   'I bet you were ready for a thick juicy steak when you got out of hospital .',
#   'I certainly was ! However , the doctor gave me a list of food I couldn ’ t eat for another 72 hours , and steak was on the list !'],
#  ['Hello . Nice to see you again . I heard you went into hospital for a few days to undergo surgery . I hope everything ’ s OK .',
#   'Yes , fine . I had something wrong with my stomach . I won ’ t go into detail , but it wasn ’ t serious .',
#   'I really dislike going to a doctor or to a hospital .',
#   'I think most people are a little nervous about it . I was really very , very nervous just before I had the operation , but the anaesthetist gave me an anaesthetic and the next thing I remember was waking up after the operation .',
#   'It must have really hurt afterwards .',
#   'Well , the nurse game me plenty of painkillers , but it did feel uncomfortable . I wasn ’ t permitted to eat anything for 48 hours . That was the worse thing .',
#   'I bet you were ready for a thick juicy steak when you got out of hospital .',
#   'I certainly was ! However , the doctor gave me a list of food I couldn ’ t eat for another 72 hours , and steak was on the list !',
#   'Is there any pain now ?'],
#  ['Hello . Nice to see you again . I heard you went into hospital for a few days to undergo surgery . I hope everything ’ s OK .',
#   'Yes , fine . I had something wrong with my stomach . I won ’ t go into detail , but it wasn ’ t serious .',
#   'I really dislike going to a doctor or to a hospital .',
#   'I think most people are a little nervous about it . I was really very , very nervous just before I had the operation , but the anaesthetist gave me an anaesthetic and the next thing I remember was waking up after the operation .',
#   'It must have really hurt afterwards .',
#   'Well , the nurse game me plenty of painkillers , but it did feel uncomfortable . I wasn ’ t permitted to eat anything for 48 hours . That was the worse thing .',
#   'I bet you were ready for a thick juicy steak when you got out of hospital .',
#   'I certainly was ! However , the doctor gave me a list of food I couldn ’ t eat for another 72 hours , and steak was on the list !',
#   'Is there any pain now ?',
#   'No , not at all . I stopped taking painkillers after a couple of days .'],
#  ['Hello . Nice to see you again . I heard you went into hospital for a few days to undergo surgery . I hope everything ’ s OK .',
#   'Yes , fine . I had something wrong with my stomach . I won ’ t go into detail , but it wasn ’ t serious .',
#   'I really dislike going to a doctor or to a hospital .',
#   'I think most people are a little nervous about it . I was really very , very nervous just before I had the operation , but the anaesthetist gave me an anaesthetic and the next thing I remember was waking up after the operation .',
#   'It must have really hurt afterwards .',
#   'Well , the nurse game me plenty of painkillers , but it did feel uncomfortable . I wasn ’ t permitted to eat anything for 48 hours . That was the worse thing .',
#   'I bet you were ready for a thick juicy steak when you got out of hospital .',
#   'I certainly was ! However , the doctor gave me a list of food I couldn ’ t eat for another 72 hours , and steak was on the list !',
#   'Is there any pain now ?',
#   'No , not at all . I stopped taking painkillers after a couple of days .',
#   'Did they take good care of you in the hospital ?'],
#  ['Hello . Nice to see you again . I heard you went into hospital for a few days to undergo surgery . I hope everything ’ s OK .',
#   'Yes , fine . I had something wrong with my stomach . I won ’ t go into detail , but it wasn ’ t serious .',
#   'I really dislike going to a doctor or to a hospital .',
#   'I think most people are a little nervous about it . I was really very , very nervous just before I had the operation , but the anaesthetist gave me an anaesthetic and the next thing I remember was waking up after the operation .',
#   'It must have really hurt afterwards .',
#   'Well , the nurse game me plenty of painkillers , but it did feel uncomfortable . I wasn ’ t permitted to eat anything for 48 hours . That was the worse thing .',
#   'I bet you were ready for a thick juicy steak when you got out of hospital .',
#   'I certainly was ! However , the doctor gave me a list of food I couldn ’ t eat for another 72 hours , and steak was on the list !',
#   'Is there any pain now ?',
#   'No , not at all . I stopped taking painkillers after a couple of days .',
#   'Did they take good care of you in the hospital ?',
#   'Oh , yes . The nurse were very kind , though they were strict about what I could drink . In the end , I just drank water and nothing else . Everyone was very professional and I actually enjoyed some aspects of my stay .'],
#  ['How was the party ?', 'I had a fantastic time .'],
#  ['Hi , Monica , how is everything going ?',
#   'Everything goes well , but I am thinking about quitting my current job .'],
#  ['Hi , Monica , how is everything going ?',
#   'Everything goes well , but I am thinking about quitting my current job .',
#   'Why ? You ’ re not satisfied anymore ?'],
#  ['Hi , Monica , how is everything going ?',
#   'Everything goes well , but I am thinking about quitting my current job .',
#   'Why ? You ’ re not satisfied anymore ?',
#   'I just sense . But I cannot grow anymore . My boss is not really supporting me . I am interested in some positions in other JV companies , but I need to do some more in-depth research before I send my application letters out .'],
#  ['Hi , Monica , how is everything going ?',
#   'Everything goes well , but I am thinking about quitting my current job .',
#   'Why ? You ’ re not satisfied anymore ?',
#   'I just sense . But I cannot grow anymore . My boss is not really supporting me . I am interested in some positions in other JV companies , but I need to do some more in-depth research before I send my application letters out .',
#   'That is important . Doing research on a company you are interested in will definitely help your application .'],
#  ['Hi , Monica , how is everything going ?',
#   'Everything goes well , but I am thinking about quitting my current job .',
#   'Why ? You ’ re not satisfied anymore ?',
#   'I just sense . But I cannot grow anymore . My boss is not really supporting me . I am interested in some positions in other JV companies , but I need to do some more in-depth research before I send my application letters out .',
#   'That is important . Doing research on a company you are interested in will definitely help your application .',
#   'Certainly , it is very nice talking with you . But I really have to go now . Catch you later .'],
#  ['Hi , Monica , how is everything going ?',
#   'Everything goes well , but I am thinking about quitting my current job .',
#   'Why ? You ’ re not satisfied anymore ?',
#   'I just sense . But I cannot grow anymore . My boss is not really supporting me . I am interested in some positions in other JV companies , but I need to do some more in-depth research before I send my application letters out .',
#   'That is important . Doing research on a company you are interested in will definitely help your application .',
#   'Certainly , it is very nice talking with you . But I really have to go now . Catch you later .',
#   'Ok , good luck to you .'],
#  ["Henry married Rose only after her father's money , didn't he ?",
#   'Yeah . But he soon feel regretted for it .'],
#  ["Henry married Rose only after her father's money , didn't he ?",
#   'Yeah . But he soon feel regretted for it .',
#   'But he seems to be very happy with Rose .'],
#  ["Henry married Rose only after her father's money , didn't he ?",
#   'Yeah . But he soon feel regretted for it .',
#   'But he seems to be very happy with Rose .',
#   'He is more nice than wise .'],
#  ['Hello , is that Cathy speaking ?', 'Yes , is that you , Allen ?'],
#  ['Hello , is that Cathy speaking ?',
#   'Yes , is that you , Allen ?',
#   'Yes , how are you doing ?'],
#  ['Hello , is that Cathy speaking ?',
#   'Yes , is that you , Allen ?',
#   'Yes , how are you doing ?',
#   'Not bad .'],
#  ['Hello , is that Cathy speaking ?',
#   'Yes , is that you , Allen ?',
#   'Yes , how are you doing ?',
#   'Not bad .',
#   "Say I've got two tickets for the concert this evening.Would you like to come with me ?"],
#  ['Hello , is that Cathy speaking ?',
#   'Yes , is that you , Allen ?',
#   'Yes , how are you doing ?',
#   'Not bad .',
#   "Say I've got two tickets for the concert this evening.Would you like to come with me ?",
#   'Sure.Thank you very much .'],
#  ['Hello , is that Cathy speaking ?',
#   'Yes , is that you , Allen ?',
#   'Yes , how are you doing ?',
#   'Not bad .',
#   "Say I've got two tickets for the concert this evening.Would you like to come with me ?",
#   'Sure.Thank you very much .',
#   "Then I ' ll pick you up at six thirty.OK ?"],
#  ['Hello , is that Cathy speaking ?',
#   'Yes , is that you , Allen ?',
#   'Yes , how are you doing ?',
#   'Not bad .',
#   "Say I've got two tickets for the concert this evening.Would you like to come with me ?",
#   'Sure.Thank you very much .',
#   "Then I ' ll pick you up at six thirty.OK ?",
#   'Ok , see you .'],
#  ['Hello , is that Cathy speaking ?',
#   'Yes , is that you , Allen ?',
#   'Yes , how are you doing ?',
#   'Not bad .',
#   "Say I've got two tickets for the concert this evening.Would you like to come with me ?",
#   'Sure.Thank you very much .',
#   "Then I ' ll pick you up at six thirty.OK ?",
#   'Ok , see you .',
#   'See you .'],
#  ['The weather has been terrible this week .',
#   "Yeah , I'm worried . If it's like this tomorrow , our big outdoor party will have to be canceled ."],
#  ['The weather has been terrible this week .',
#   "Yeah , I'm worried . If it's like this tomorrow , our big outdoor party will have to be canceled .",
#   "Let's hope it clears up ."],
#  ['Is that pesky lady coming to the office again ?', "Yeah , I'm afraid so ."],
#  ['Is that pesky lady coming to the office again ?',
#   "Yeah , I'm afraid so .",
#   "If there's one thing that bugs me , it's her critical attitude ."],
#  ['Is that pesky lady coming to the office again ?',
#   "Yeah , I'm afraid so .",
#   "If there's one thing that bugs me , it's her critical attitude .",
#   'Yes , it is annoying .'],
#  ["Hi , Mr . Smith . what's new ?", 'Nothing particular . But , ...'],
#  ["Hi , Mr . Smith . what's new ?",
#   'Nothing particular . But , ...',
#   "What's the matter ?"],
#  ["Hi , Mr . Smith . what's new ?",
#   'Nothing particular . But , ...',
#   "What's the matter ?",
#   "I , I don't know how to explain it to you ."],
#  ["Hi , Mr . Smith . what's new ?",
#   'Nothing particular . But , ...',
#   "What's the matter ?",
#   "I , I don't know how to explain it to you .",
#   "Go ahead . It's nothing serious . We are good friends , aren't we ?"],
#  ["Hi , Mr . Smith . what's new ?",
#   'Nothing particular . But , ...',
#   "What's the matter ?",
#   "I , I don't know how to explain it to you .",
#   "Go ahead . It's nothing serious . We are good friends , aren't we ?",
#   "Yes , of course . But I'm afraid I can't tell you ."],
#  ['How do you do ?',
#   'How do you do ? Nice to meet you , Ms . Smith . I ’ m Jack Stevens from the Marketing Department . Here is my card .'],
#  ['How do you do ?',
#   'How do you do ? Nice to meet you , Ms . Smith . I ’ m Jack Stevens from the Marketing Department . Here is my card .',
#   'It ’ s nice to meet you , Mr . Stevens .'],
#  ['How do you do ?',
#   'How do you do ? Nice to meet you , Ms . Smith . I ’ m Jack Stevens from the Marketing Department . Here is my card .',
#   'It ’ s nice to meet you , Mr . Stevens .',
#   'Please call me Jack . Have a seat , please .'],
#  ['How do you do ?',
#   'How do you do ? Nice to meet you , Ms . Smith . I ’ m Jack Stevens from the Marketing Department . Here is my card .',
#   'It ’ s nice to meet you , Mr . Stevens .',
#   'Please call me Jack . Have a seat , please .',
#   'Thank you .'],
#  ['Thanks for your hospitality .', "You're welcome ."],
#  ["I'm terribly sorry to have caused you so much trouble .",
#   "That's all right ."],
#  ["Hey , what's new ?",
#   "Not much . Just sitting here eating some Chinese food . Is that the paper ? Why don't you open it and tell me my horoscope ?"],
#  ["Hey , what's new ?",
#   "Not much . Just sitting here eating some Chinese food . Is that the paper ? Why don't you open it and tell me my horoscope ?",
#   "Ok , wait a minute ... let's see . I'm a Taurus , and it says , Mars is in the third house , and is soon to eclipse Venus . I don't know what that means , but then it says , Your charm and drive will win others over to your way of thinking . Remember to be positive . Sounds good to me ."],
#  ["Hey , what's new ?",
#   "Not much . Just sitting here eating some Chinese food . Is that the paper ? Why don't you open it and tell me my horoscope ?",
#   "Ok , wait a minute ... let's see . I'm a Taurus , and it says , Mars is in the third house , and is soon to eclipse Venus . I don't know what that means , but then it says , Your charm and drive will win others over to your way of thinking . Remember to be positive . Sounds good to me .",
#   "What about Gemini ? What's the prediction ?"],
#  ["Hey , what's new ?",
#   "Not much . Just sitting here eating some Chinese food . Is that the paper ? Why don't you open it and tell me my horoscope ?",
#   "Ok , wait a minute ... let's see . I'm a Taurus , and it says , Mars is in the third house , and is soon to eclipse Venus . I don't know what that means , but then it says , Your charm and drive will win others over to your way of thinking . Remember to be positive . Sounds good to me .",
#   "What about Gemini ? What's the prediction ?",
#   'Since Mercury has crossed paths with Jupiter , your fortunes are falling . Bad luck will follow you today , and you will lose that which you value . Be careful .'],
#  ["Hey , what's new ?",
#   "Not much . Just sitting here eating some Chinese food . Is that the paper ? Why don't you open it and tell me my horoscope ?",
#   "Ok , wait a minute ... let's see . I'm a Taurus , and it says , Mars is in the third house , and is soon to eclipse Venus . I don't know what that means , but then it says , Your charm and drive will win others over to your way of thinking . Remember to be positive . Sounds good to me .",
#   "What about Gemini ? What's the prediction ?",
#   'Since Mercury has crossed paths with Jupiter , your fortunes are falling . Bad luck will follow you today , and you will lose that which you value . Be careful .',
#   "That sounds bad ! I'm really worried , what should I do ? Maybe I should go home and stay in the rest of the day ."],
#  ["Hey , what's new ?",
#   "Not much . Just sitting here eating some Chinese food . Is that the paper ? Why don't you open it and tell me my horoscope ?",
#   "Ok , wait a minute ... let's see . I'm a Taurus , and it says , Mars is in the third house , and is soon to eclipse Venus . I don't know what that means , but then it says , Your charm and drive will win others over to your way of thinking . Remember to be positive . Sounds good to me .",
#   "What about Gemini ? What's the prediction ?",
#   'Since Mercury has crossed paths with Jupiter , your fortunes are falling . Bad luck will follow you today , and you will lose that which you value . Be careful .',
#   "That sounds bad ! I'm really worried , what should I do ? Maybe I should go home and stay in the rest of the day .",
#   "But we have a date tonight ! You can't stay at home because of a stupid horoscope ."],
#  ['Lily , can you take part in our picnic this weekend ?',
#   'That sounds great . Where are you going ?'],
#  ['Lily , can you take part in our picnic this weekend ?',
#   'That sounds great . Where are you going ?',
#   'I think we can go to the river , go around and have supper .'],
#  ['Lily , can you take part in our picnic this weekend ?',
#   'That sounds great . Where are you going ?',
#   'I think we can go to the river , go around and have supper .',
#   'What should I bring ?'],
#  ['Lily , can you take part in our picnic this weekend ?',
#   'That sounds great . Where are you going ?',
#   'I think we can go to the river , go around and have supper .',
#   'What should I bring ?',
#   "Nothing . Just wear comfortable clothes and good shoes for walking . We'll bring everything ."],
#  ['What do you think of doctor Thomson ?',
#   "I feel confident of his ability to cure my daughter's disease ."],
#  ['What do you think of doctor Thomson ?',
#   "I feel confident of his ability to cure my daughter's disease .",
#   'How can you be so sure ?'],
#  ['What do you think of doctor Thomson ?',
#   "I feel confident of his ability to cure my daughter's disease .",
#   'How can you be so sure ?',
#   'I can tell form the way he spoke to us .'],
#  ['What do you think of doctor Thomson ?',
#   "I feel confident of his ability to cure my daughter's disease .",
#   'How can you be so sure ?',
#   'I can tell form the way he spoke to us .',
#   'Never believe his words .'],
#  ["Should we ask Jason to play ? He's always watching movies on HBO .",
#   "I guess we should invite him . I just hope he doesn't start talking about Sylvester Stallone and Arnold Schwarzenegger again ."],
#  ["Should we ask Jason to play ? He's always watching movies on HBO .",
#   "I guess we should invite him . I just hope he doesn't start talking about Sylvester Stallone and Arnold Schwarzenegger again .",
#   "Oh , come on ! The game is better with three people . Anyway , if we don't ask him to play , he'll be mad ."],
#  ["Should we ask Jason to play ? He's always watching movies on HBO .",
#   "I guess we should invite him . I just hope he doesn't start talking about Sylvester Stallone and Arnold Schwarzenegger again .",
#   "Oh , come on ! The game is better with three people . Anyway , if we don't ask him to play , he'll be mad .",
#   "Yeah , you're right . We'll never hear the end of it ."],
#  ['What do you think about violence in movies ?',
#   "Personally , I'm not for it . I feel it's bad for kids to watch ."],
#  ['What do you think about violence in movies ?',
#   "Personally , I'm not for it . I feel it's bad for kids to watch .",
#   "But kids like watching things like that . It's just for fun , would't you say ?"],
#  ['What do you think about violence in movies ?',
#   "Personally , I'm not for it . I feel it's bad for kids to watch .",
#   "But kids like watching things like that . It's just for fun , would't you say ?",
#   "If you ask me , I have to disagree . Something shouldn't be watched for fun ."],
#  ['Are you free tomorrow night ?', 'Yes , I am .'],
#  ['Are you free tomorrow night ?',
#   'Yes , I am .',
#   'Shall we have dinner together ?'],
#  ['Are you free tomorrow night ?',
#   'Yes , I am .',
#   'Shall we have dinner together ?',
#   'Do you have a special restaurant in mind ?'],
#  ['Are you free tomorrow night ?',
#   'Yes , I am .',
#   'Shall we have dinner together ?',
#   'Do you have a special restaurant in mind ?',
#   'Yes , I do . I know a place that has excellent food .'],
#  ['Are you free tomorrow night ?',
#   'Yes , I am .',
#   'Shall we have dinner together ?',
#   'Do you have a special restaurant in mind ?',
#   'Yes , I do . I know a place that has excellent food .',
#   "OK . I'll be happy to join you ."],
#  ['If only our company prescribe flex time .',
#   'The board has been considering introducing flex time .'],
#  ['If only our company prescribe flex time .',
#   'The board has been considering introducing flex time .',
#   'Good news . Ah , what if be even better if alternative work place is provided .'],
#  ['If only our company prescribe flex time .',
#   'The board has been considering introducing flex time .',
#   'Good news . Ah , what if be even better if alternative work place is provided .',
#   'Then our entire job could be done by telecommuting .'],
#  ['Brian , do you know how to speak English ?', 'Yes .'],
#  ['Brian , do you know how to speak English ?',
#   'Yes .',
#   'Where did you learn ?'],
#  ['Brian , do you know how to speak English ?',
#   'Yes .',
#   'Where did you learn ?',
#   'I learned in college .'],
#  ['Brian , do you know how to speak English ?',
#   'Yes .',
#   'Where did you learn ?',
#   'I learned in college .',
#   'You speak really well .'],
#  ['Brian , do you know how to speak English ?',
#   'Yes .',
#   'Where did you learn ?',
#   'I learned in college .',
#   'You speak really well .',
#   'Thank you .'],
#  ['Brian , do you know how to speak English ?',
#   'Yes .',
#   'Where did you learn ?',
#   'I learned in college .',
#   'You speak really well .',
#   'Thank you .',
#   'How long have you been in the U . S . ?'],
#  ['Brian , do you know how to speak English ?',
#   'Yes .',
#   'Where did you learn ?',
#   'I learned in college .',
#   'You speak really well .',
#   'Thank you .',
#   'How long have you been in the U . S . ?',
#   '3 weeks .'],
#  ['Brian , do you know how to speak English ?',
#   'Yes .',
#   'Where did you learn ?',
#   'I learned in college .',
#   'You speak really well .',
#   'Thank you .',
#   'How long have you been in the U . S . ?',
#   '3 weeks .',
#   'Is your wife with you ?'],
#  ['Brian , do you know how to speak English ?',
#   'Yes .',
#   'Where did you learn ?',
#   'I learned in college .',
#   'You speak really well .',
#   'Thank you .',
#   'How long have you been in the U . S . ?',
#   '3 weeks .',
#   'Is your wife with you ?',
#   'Yes , she just got here yesterday .'],
#  ['Brian , do you know how to speak English ?',
#   'Yes .',
#   'Where did you learn ?',
#   'I learned in college .',
#   'You speak really well .',
#   'Thank you .',
#   'How long have you been in the U . S . ?',
#   '3 weeks .',
#   'Is your wife with you ?',
#   'Yes , she just got here yesterday .',
#   'Have you been to California before ?'],
#  ['Brian , do you know how to speak English ?',
#   'Yes .',
#   'Where did you learn ?',
#   'I learned in college .',
#   'You speak really well .',
#   'Thank you .',
#   'How long have you been in the U . S . ?',
#   '3 weeks .',
#   'Is your wife with you ?',
#   'Yes , she just got here yesterday .',
#   'Have you been to California before ?',
#   "No . I've never been there ."],
#  ['Brian , do you know how to speak English ?',
#   'Yes .',
#   'Where did you learn ?',
#   'I learned in college .',
#   'You speak really well .',
#   'Thank you .',
#   'How long have you been in the U . S . ?',
#   '3 weeks .',
#   'Is your wife with you ?',
#   'Yes , she just got here yesterday .',
#   'Have you been to California before ?',
#   "No . I've never been there .",
#   'Have you ever been to Las Vegas ?'],
#  ['Brian , do you know how to speak English ?',
#   'Yes .',
#   'Where did you learn ?',
#   'I learned in college .',
#   'You speak really well .',
#   'Thank you .',
#   'How long have you been in the U . S . ?',
#   '3 weeks .',
#   'Is your wife with you ?',
#   'Yes , she just got here yesterday .',
#   'Have you been to California before ?',
#   "No . I've never been there .",
#   'Have you ever been to Las Vegas ?',
#   'Yes . I went there once on a business trip .'],
#  ['How are the children doing at sport ?',
#   'I ’ m very pleased with their performances . Timmy can cover the 100 meters in 12 seconds . That ’ s very fast for a kid his age .'],
#  ['How are the children doing at sport ?',
#   'I ’ m very pleased with their performances . Timmy can cover the 100 meters in 12 seconds . That ’ s very fast for a kid his age .',
#   'He ’ s not very good at the long jump though , is he ?'],
#  ['How are the children doing at sport ?',
#   'I ’ m very pleased with their performances . Timmy can cover the 100 meters in 12 seconds . That ’ s very fast for a kid his age .',
#   'He ’ s not very good at the long jump though , is he ?',
#   'He ’ s not bad . He can jump a distance of over four meters . I think he just prefers running to jumping . Jimmy ’ s very good at the high jump . He can jump over two meters . Again , that ’ s fine for someone his age .'],
#  ['How are the children doing at sport ?',
#   'I ’ m very pleased with their performances . Timmy can cover the 100 meters in 12 seconds . That ’ s very fast for a kid his age .',
#   'He ’ s not very good at the long jump though , is he ?',
#   'He ’ s not bad . He can jump a distance of over four meters . I think he just prefers running to jumping . Jimmy ’ s very good at the high jump . He can jump over two meters . Again , that ’ s fine for someone his age .',
#   'Two meters ? That means that the high jump bar is above his head ! Are any of them good at long-distance running ?'],
#  ['How are the children doing at sport ?',
#   'I ’ m very pleased with their performances . Timmy can cover the 100 meters in 12 seconds . That ’ s very fast for a kid his age .',
#   'He ’ s not very good at the long jump though , is he ?',
#   'He ’ s not bad . He can jump a distance of over four meters . I think he just prefers running to jumping . Jimmy ’ s very good at the high jump . He can jump over two meters . Again , that ’ s fine for someone his age .',
#   'Two meters ? That means that the high jump bar is above his head ! Are any of them good at long-distance running ?',
#   'The longest race we run is the 1500 meters . A few of the boys and one girls can do it in less than five minutes .'],
#  ['How are the children doing at sport ?',
#   'I ’ m very pleased with their performances . Timmy can cover the 100 meters in 12 seconds . That ’ s very fast for a kid his age .',
#   'He ’ s not very good at the long jump though , is he ?',
#   'He ’ s not bad . He can jump a distance of over four meters . I think he just prefers running to jumping . Jimmy ’ s very good at the high jump . He can jump over two meters . Again , that ’ s fine for someone his age .',
#   'Two meters ? That means that the high jump bar is above his head ! Are any of them good at long-distance running ?',
#   'The longest race we run is the 1500 meters . A few of the boys and one girls can do it in less than five minutes .',
#   'How are they at swimming ?'],
#  ['How are the children doing at sport ?',
#   'I ’ m very pleased with their performances . Timmy can cover the 100 meters in 12 seconds . That ’ s very fast for a kid his age .',
#   'He ’ s not very good at the long jump though , is he ?',
#   'He ’ s not bad . He can jump a distance of over four meters . I think he just prefers running to jumping . Jimmy ’ s very good at the high jump . He can jump over two meters . Again , that ’ s fine for someone his age .',
# ...
#   'Totally agree . What is your solution ?'],
#  ['Do you sometimes feel overwhelmed by your work ?',
#   'Of course ! It is the No . 1 stressor in my life . You know job stress has become a very common problem these days . So we must learn to cope with it .',
#   'Totally agree . What is your solution ?',
#   'Well , there are two causes of job stress . One is employee characteristic and the other is company condition . So if we want to manage job stress , both we and the companies should do something . For me , I am trying to balance work and leisure time . You know , all work and no play make Jack a dull boy .'],
#  ['Do you sometimes feel overwhelmed by your work ?',
#   'Of course ! It is the No . 1 stressor in my life . You know job stress has become a very common problem these days . So we must learn to cope with it .',
#   'Totally agree . What is your solution ?',
#   'Well , there are two causes of job stress . One is employee characteristic and the other is company condition . So if we want to manage job stress , both we and the companies should do something . For me , I am trying to balance work and leisure time . You know , all work and no play make Jack a dull boy .',
#   'You seem to have a very relaxed outlook .'],
#  ['Do you sometimes feel overwhelmed by your work ?',
#   'Of course ! It is the No . 1 stressor in my life . You know job stress has become a very common problem these days . So we must learn to cope with it .',
#   'Totally agree . What is your solution ?',
#   'Well , there are two causes of job stress . One is employee characteristic and the other is company condition . So if we want to manage job stress , both we and the companies should do something . For me , I am trying to balance work and leisure time . You know , all work and no play make Jack a dull boy .',
#   'You seem to have a very relaxed outlook .',
#   'It is necessary . Positive attitude helps to prevent stress .'],
#  ['Do you sometimes feel overwhelmed by your work ?',
#   'Of course ! It is the No . 1 stressor in my life . You know job stress has become a very common problem these days . So we must learn to cope with it .',
#   'Totally agree . What is your solution ?',
#   'Well , there are two causes of job stress . One is employee characteristic and the other is company condition . So if we want to manage job stress , both we and the companies should do something . For me , I am trying to balance work and leisure time . You know , all work and no play make Jack a dull boy .',
#   'You seem to have a very relaxed outlook .',
#   'It is necessary . Positive attitude helps to prevent stress .',
#   'But I don ’ t think we can change our working condition . Anyway , we are not the bosses .'],
#  ['Do you sometimes feel overwhelmed by your work ?',
#   'Of course ! It is the No . 1 stressor in my life . You know job stress has become a very common problem these days . So we must learn to cope with it .',
#   'Totally agree . What is your solution ?',
#   'Well , there are two causes of job stress . One is employee characteristic and the other is company condition . So if we want to manage job stress , both we and the companies should do something . For me , I am trying to balance work and leisure time . You know , all work and no play make Jack a dull boy .',
#   'You seem to have a very relaxed outlook .',
#   'It is necessary . Positive attitude helps to prevent stress .',
#   'But I don ’ t think we can change our working condition . Anyway , we are not the bosses .',
#   'I heard some companies are providing stress management training and making changes inside them , like avoiding unrealistic deadlines and organizing relaxation activities . Our boss is a smart person . He will be learning from that if he would like to an efficient and healthy team .'],
#  ['I am so busy today .', 'Can I help you ?'],
#  ['I am so busy today .',
#   'Can I help you ?',
#   'I ’ m not sure . Perhaps you could do the shopping .'],
#  ['I am so busy today .',
#   'Can I help you ?',
#   'I ’ m not sure . Perhaps you could do the shopping .',
#   'I ’ ll be glad to help .'],
#  ['I am so busy today .',
#   'Can I help you ?',
#   'I ’ m not sure . Perhaps you could do the shopping .',
#   'I ’ ll be glad to help .',
#   'Or maybe make the beds .'],
#  ['I am so busy today .',
#   'Can I help you ?',
#   'I ’ m not sure . Perhaps you could do the shopping .',
#   'I ’ ll be glad to help .',
#   'Or maybe make the beds .',
#   'All you have to do is ask for help .'],
#  ['I am so busy today .',
#   'Can I help you ?',
#   'I ’ m not sure . Perhaps you could do the shopping .',
#   'I ’ ll be glad to help .',
#   'Or maybe make the beds .',
#   'All you have to do is ask for help .',
#   'Thanks . That ’ s terrific !'],
#  ['I am so busy today .',
#   'Can I help you ?',
#   'I ’ m not sure . Perhaps you could do the shopping .',
#   'I ’ ll be glad to help .',
#   'Or maybe make the beds .',
#   'All you have to do is ask for help .',
#   'Thanks . That ’ s terrific !',
#   'I ’ m ready and willing to help .'],
#  ['The restaurant across the street hired a new Chinese chef , so I ordered some Chinese food there for this evening .',
#   'Good . I love Chinese food . What did you order ?'],
#  ['The restaurant across the street hired a new Chinese chef , so I ordered some Chinese food there for this evening .',
#   'Good . I love Chinese food . What did you order ?',
#   'Something hot and spicy . They look very inviting on the menu . You are going to love them .'],
#  ['The restaurant across the street hired a new Chinese chef , so I ordered some Chinese food there for this evening .',
#   'Good . I love Chinese food . What did you order ?',
#   'Something hot and spicy . They look very inviting on the menu . You are going to love them .',
#   "Maybe we can find a place to learn some Chinese cooking . I hear there's a place in Chinatown where you can take some courses . Are you interested ?"],
#  ['The restaurant across the street hired a new Chinese chef , so I ordered some Chinese food there for this evening .',
#   'Good . I love Chinese food . What did you order ?',
#   'Something hot and spicy . They look very inviting on the menu . You are going to love them .',
#   "Maybe we can find a place to learn some Chinese cooking . I hear there's a place in Chinatown where you can take some courses . Are you interested ?",
#   "I'm not sure . I don't enjoy cooking that much . As long as we can order it from a restaurant , we don't have to learn to do it by ourselves ."],
#  ['The restaurant across the street hired a new Chinese chef , so I ordered some Chinese food there for this evening .',
#   'Good . I love Chinese food . What did you order ?',
#   'Something hot and spicy . They look very inviting on the menu . You are going to love them .',
#   "Maybe we can find a place to learn some Chinese cooking . I hear there's a place in Chinatown where you can take some courses . Are you interested ?",
#   "I'm not sure . I don't enjoy cooking that much . As long as we can order it from a restaurant , we don't have to learn to do it by ourselves .",
#   'You are right . But I just want to know how they prepare food and make it taste so different .'],
#  ["You don't look too well . Maybe you should take the day off from work .",
#   "I couldn't do that . I have an important meeting to go to today ."],
#  ["You don't look too well . Maybe you should take the day off from work .",
#   "I couldn't do that . I have an important meeting to go to today .",
#   'Do you feel ok ?'],
#  ["You don't look too well . Maybe you should take the day off from work .",
#   "I couldn't do that . I have an important meeting to go to today .",
#   'Do you feel ok ?',
#   "Not really . After a 12 - hour flight , I've got jetlag , and on top of that , I think I've also got the flu ."],
#  ["You don't look too well . Maybe you should take the day off from work .",
#   "I couldn't do that . I have an important meeting to go to today .",
#   'Do you feel ok ?',
#   "Not really . After a 12 - hour flight , I've got jetlag , and on top of that , I think I've also got the flu .",
#   "Why don't you call your secretary and tell her to reschedule the meeting ? You should really get some rest or you'll end up feeling even worse than you do now ."],
#  ["You don't look too well . Maybe you should take the day off from work .",
#   "I couldn't do that . I have an important meeting to go to today .",
#   'Do you feel ok ?',
#   "Not really . After a 12 - hour flight , I've got jetlag , and on top of that , I think I've also got the flu .",
#   "Why don't you call your secretary and tell her to reschedule the meeting ? You should really get some rest or you'll end up feeling even worse than you do now .",
#   'Could you feel my forehead and check to see if I have a fever ?'],
#  ["You don't look too well . Maybe you should take the day off from work .",
#   "I couldn't do that . I have an important meeting to go to today .",
#   'Do you feel ok ?',
#   "Not really . After a 12 - hour flight , I've got jetlag , and on top of that , I think I've also got the flu .",
#   "Why don't you call your secretary and tell her to reschedule the meeting ? You should really get some rest or you'll end up feeling even worse than you do now .",
#   'Could you feel my forehead and check to see if I have a fever ?',
#   "You're really hot . Let me get you some Tylenol to bring the fever down ."],
#  ["You don't look too well . Maybe you should take the day off from work .",
#   "I couldn't do that . I have an important meeting to go to today .",
#   'Do you feel ok ?',
#   "Not really . After a 12 - hour flight , I've got jetlag , and on top of that , I think I've also got the flu .",
#   "Why don't you call your secretary and tell her to reschedule the meeting ? You should really get some rest or you'll end up feeling even worse than you do now .",
#   'Could you feel my forehead and check to see if I have a fever ?',
#   "You're really hot . Let me get you some Tylenol to bring the fever down .",
#   "Ok . I'll stay home this morning and rest , but if I feel better in the afternoon , I'm going to the meeting ."],
#  ["You don't look too well . Maybe you should take the day off from work .",
#   "I couldn't do that . I have an important meeting to go to today .",
#   'Do you feel ok ?',
#   "Not really . After a 12 - hour flight , I've got jetlag , and on top of that , I think I've also got the flu .",
#   "Why don't you call your secretary and tell her to reschedule the meeting ? You should really get some rest or you'll end up feeling even worse than you do now .",
#   'Could you feel my forehead and check to see if I have a fever ?',
#   "You're really hot . Let me get you some Tylenol to bring the fever down .",
#   "Ok . I'll stay home this morning and rest , but if I feel better in the afternoon , I'm going to the meeting .",
#   "Zach , what's that on your arm ?"],
#  ["You don't look too well . Maybe you should take the day off from work .",
#   "I couldn't do that . I have an important meeting to go to today .",
#   'Do you feel ok ?',
#   "Not really . After a 12 - hour flight , I've got jetlag , and on top of that , I think I've also got the flu .",
#   "Why don't you call your secretary and tell her to reschedule the meeting ? You should really get some rest or you'll end up feeling even worse than you do now .",
#   'Could you feel my forehead and check to see if I have a fever ?',
#   "You're really hot . Let me get you some Tylenol to bring the fever down .",
#   "Ok . I'll stay home this morning and rest , but if I feel better in the afternoon , I'm going to the meeting .",
#   "Zach , what's that on your arm ?",
#   "I don't know . It looks a bit red , but I'm sure it's nothing ."],
#  ["You don't look too well . Maybe you should take the day off from work .",
#   "I couldn't do that . I have an important meeting to go to today .",
#   'Do you feel ok ?',
#   "Not really . After a 12 - hour flight , I've got jetlag , and on top of that , I think I've also got the flu .",
#   "Why don't you call your secretary and tell her to reschedule the meeting ? You should really get some rest or you'll end up feeling even worse than you do now .",
#   'Could you feel my forehead and check to see if I have a fever ?',
#   "You're really hot . Let me get you some Tylenol to bring the fever down .",
#   "Ok . I'll stay home this morning and rest , but if I feel better in the afternoon , I'm going to the meeting .",
#   "Zach , what's that on your arm ?",
#   "I don't know . It looks a bit red , but I'm sure it's nothing .",
#   'It looks like you have a red rash all over you ! Are you allergic to anything ?'],
#  ["You don't look too well . Maybe you should take the day off from work .",
#   "I couldn't do that . I have an important meeting to go to today .",
#   'Do you feel ok ?',
#   "Not really . After a 12 - hour flight , I've got jetlag , and on top of that , I think I've also got the flu .",
#   "Why don't you call your secretary and tell her to reschedule the meeting ? You should really get some rest or you'll end up feeling even worse than you do now .",
#   'Could you feel my forehead and check to see if I have a fever ?',
#   "You're really hot . Let me get you some Tylenol to bring the fever down .",
#   "Ok . I'll stay home this morning and rest , but if I feel better in the afternoon , I'm going to the meeting .",
#   "Zach , what's that on your arm ?",
#   "I don't know . It looks a bit red , but I'm sure it's nothing .",
#   'It looks like you have a red rash all over you ! Are you allergic to anything ?',
#   "Just cats , but I don't think I was near any cats in the last couple of weeks ."],
#  ["You don't look too well . Maybe you should take the day off from work .",
#   "I couldn't do that . I have an important meeting to go to today .",
#   'Do you feel ok ?',
#   "Not really . After a 12 - hour flight , I've got jetlag , and on top of that , I think I've also got the flu .",
#   "Why don't you call your secretary and tell her to reschedule the meeting ? You should really get some rest or you'll end up feeling even worse than you do now .",
#   'Could you feel my forehead and check to see if I have a fever ?',
#   "You're really hot . Let me get you some Tylenol to bring the fever down .",
#   "Ok . I'll stay home this morning and rest , but if I feel better in the afternoon , I'm going to the meeting .",
#   "Zach , what's that on your arm ?",
#   "I don't know . It looks a bit red , but I'm sure it's nothing .",
#   'It looks like you have a red rash all over you ! Are you allergic to anything ?',
#   "Just cats , but I don't think I was near any cats in the last couple of weeks .",
#   "I completely forgot about your cat allergy . I took care of a cat for my friend here a few days ago . Oh no . we'd better go to the doctor and get some medicine . Let's go ."],
#  ["You don't look too well . Maybe you should take the day off from work .",
#   "I couldn't do that . I have an important meeting to go to today .",
#   'Do you feel ok ?',
#   "Not really . After a 12 - hour flight , I've got jetlag , and on top of that , I think I've also got the flu .",
#   "Why don't you call your secretary and tell her to reschedule the meeting ? You should really get some rest or you'll end up feeling even worse than you do now .",
#   'Could you feel my forehead and check to see if I have a fever ?',
#   "You're really hot . Let me get you some Tylenol to bring the fever down .",
#   "Ok . I'll stay home this morning and rest , but if I feel better in the afternoon , I'm going to the meeting .",
#   "Zach , what's that on your arm ?",
#   "I don't know . It looks a bit red , but I'm sure it's nothing .",
#   'It looks like you have a red rash all over you ! Are you allergic to anything ?',
#   "Just cats , but I don't think I was near any cats in the last couple of weeks .",
#   "I completely forgot about your cat allergy . I took care of a cat for my friend here a few days ago . Oh no . we'd better go to the doctor and get some medicine . Let's go .",
#   "Shouldn't we make an appointment first ?"],
#  ...]

# %% [markdown]
# 写一个推理函数
# 函数=》 输入一个英文句子 回答 一个英文句子 对话 =》 多轮对话

# %%
tokenizer.encode('i like playing basketball')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-20ed40ca5170> in <module>
# ----> 1 tokenizer.encode('i like playing basketball')
#
# NameError: name 'tokenizer' is not defined

# %%
tokenizer.decode([72,588,2712,9669])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-5e8ff79182a0> in <module>
# ----> 1 tokenizer.decode([72,588,2712,9669])
#
# NameError: name 'tokenizer' is not defined

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
weights = torch.load('../Data_source/medium_ft.pkl')
medium_config = GPT2Config(n_embd = 1024,n_layer = 24, n_head = 16)
model = GPT2LMHeadModel(medium_config)

weights['lm_head.weight'] = weights['lm_head.decoder.weight']
weights.pop('lm_head.decoder.weight',None)

model.load_state_dict(weights)
model.train()
#model.to('cuda')
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 1024)
#     (wpe): Embedding(1024, 1024)
#     (drop): Dropout(p=0.1)
#     (h): ModuleList(
#       (0): Block(
#         (ln_1): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1)
#           (resid_dropout): Dropout(p=0.1)
#         )
#         (ln_2): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (1): Block(
#         (ln_1): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1)
#           (resid_dropout): Dropout(p=0.1)
#         )
#         (ln_2): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (2): Block(
#         (ln_1): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1)
#           (resid_dropout): Dropout(p=0.1)
#         )
#         (ln_2): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (3): Block(
#         (ln_1): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1)
#           (resid_dropout): Dropout(p=0.1)
#         )
#         (ln_2): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (4): Block(
#         (ln_1): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1)
#           (resid_dropout): Dropout(p=0.1)
#         )
#         (ln_2): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (5): Block(
#         (ln_1): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1)
#           (resid_dropout): Dropout(p=0.1)
#         )
#         (ln_2): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (6): Block(
#         (ln_1): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1)
#           (resid_dropout): Dropout(p=0.1)
#         )
#         (ln_2): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (7): Block(
#         (ln_1): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1)
#           (resid_dropout): Dropout(p=0.1)
#         )
#         (ln_2): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (8): Block(
#         (ln_1): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1)
#           (resid_dropout): Dropout(p=0.1)
#         )
#         (ln_2): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (9): Block(
#         (ln_1): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1)
#           (resid_dropout): Dropout(p=0.1)
#         )
#         (ln_2): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (10): Block(
#         (ln_1): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1)
#           (resid_dropout): Dropout(p=0.1)
#         )
#         (ln_2): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (11): Block(
#         (ln_1): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1)
#           (resid_dropout): Dropout(p=0.1)
#         )
#         (ln_2): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (12): Block(
#         (ln_1): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1)
#           (resid_dropout): Dropout(p=0.1)
#         )
#         (ln_2): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (13): Block(
#         (ln_1): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1)
#           (resid_dropout): Dropout(p=0.1)
#         )
#         (ln_2): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (14): Block(
#         (ln_1): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1)
#           (resid_dropout): Dropout(p=0.1)
#         )
#         (ln_2): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (15): Block(
#         (ln_1): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1)
#           (resid_dropout): Dropout(p=0.1)
#         )
#         (ln_2): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (16): Block(
#         (ln_1): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1)
#           (resid_dropout): Dropout(p=0.1)
#         )
#         (ln_2): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (17): Block(
#         (ln_1): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1)
#           (resid_dropout): Dropout(p=0.1)
#         )
#         (ln_2): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (18): Block(
#         (ln_1): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1)
#           (resid_dropout): Dropout(p=0.1)
#         )
#         (ln_2): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (19): Block(
#         (ln_1): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1)
#           (resid_dropout): Dropout(p=0.1)
#         )
#         (ln_2): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (20): Block(
#         (ln_1): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1)
#           (resid_dropout): Dropout(p=0.1)
#         )
#         (ln_2): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (21): Block(
#         (ln_1): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1)
#           (resid_dropout): Dropout(p=0.1)
#         )
#         (ln_2): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (22): Block(
#         (ln_1): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1)
#           (resid_dropout): Dropout(p=0.1)
#         )
#         (ln_2): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#       (23): Block(
#         (ln_1): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1)
#           (resid_dropout): Dropout(p=0.1)
#         )
#         (ln_2): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1)
#         )
#       )
#     )
#     (ln_f): LayerNorm(torch.Size([1024]), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=1024, out_features=50257, bias=False)
# )

# %%
class InputFeature(object):
    def __init__(self,input_ids,position_ids,token_type_ids,
                lm_labels=None,input_len=None):
        
        self.input_ids = input_ids
        self.position_ids = position_ids
        self.token_type_ids = token_type_ids
        self.lm_lanels =lm_labels
        if input_len is None:
            self.input_len = len(input_ids)
        else:
            self.input_len = input_len

# %%
class GPT2Dataset(Dataset):
    
    def __init__(self,dials,max_len = 1024):
        self.max_len = max_len
        self.features = build_input_feature(dials)
    
    def __getitem__(slef,i):
        feat_dict = self.features[i]
        if self.max_len is not None and feat_dict['input_len'] > self.max_len:
            feat_dict['input_ids'] = feat_dict['input_dis'][-self.max_len:]
            feat_dict['position_ids'] = feat_dict['position_ids'][-self.max_len:]
            feat_dict['token_type_ids'] = feat_dict['token_type_ids'][-self.max_len:]
            feat_dict['lm_labels'] = feat_dict['lm_labels'][-self.max_len:]
        feat = InputFeaturet(**feat_dict)
        return feat
    
    def __len__(self):
        return len(self.features)
    
    @staticmethod
    def build_input_feature(dials,end_text='<|endoftext|>'):
        tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
        feature = []
        for dial in dials:
            inputs = sum([tokenizer.encode(u) for u in dial[:-1]],[])
            lm_labels = [-1]*len(inputs) + tokenizer.encode(dial[-1] + end_text)
            token_type_ids = [0] * len(inputs) + [1.0] * (len(tokenizer.encode(dial[-1] + end_text)))
            input_ids = inputs + tokenizer.encode(end_text + dial[-1])
            input_len = len(input_ids)
            position_ids = list(range(len(input_ids)))
            
            feat_dict = {'input_ids':input_ids,
                        'position_ids':position_ids,
                        'token_type_ids':token_type_ids,
                        'lm_labels':lm_labels,
                        'input_len':input_len}
            feature.append(feat_dict)
        return feature
    
    @staticmethod
    def collate(features):
        inputs_ids = pad_sequence([torch.tensor(f['input_ids'],dtype=torch.long)
                                  for f in features],batch_first=True,padding_value=0)
        
        position_ids = pad_sequence([torch.tensor(f['position_ids'],dtype=torch.long)
                                   for f in features],batch_first=True,padding_value=0)
        
        token_type_ids = pad_sequence([torch.tensor(f['token_type_ids'],dtype=torch.long)
                                      for f in features],batch_first=True,padding_value=0)
        
        labels = pad_sequence([torch.tensor(f['lm_labels'],dtype=torch.long)
                              for f in features],batch_first=True,padding_value=-1)
        
        return (inputs_ids,position_ids,token_type_ids,labels)

# %%
dataset = GPT2Dataset.build_input_feature(dials)

# %%
loader = DataLoader(dataset,collate_fn=GPT2Dataset.collate,batch_size=1)

# %%
def run(model,train_dataloader,learning_rate,epoches):
    
    optimizer = Adam(model.parameters(),lr=learning_rate)
    step = 0
    epoch = 0 
    
    pbar = tqdm(enumerate(train_dataloader),total=len(train_dataloader))
    loss_function  = CrossEntropyLoss(ignore_index=-1,reduction='mean')
    while epoch < epoches:
        running_loss = 0 
        try:
            with tqdm(enumerate(train_dataloader),total=len(train_dataloader)) as pbar:
                for i,batch in pbar:
                    input_ids,position_ids,token_type_ids,label_ids = batch
                    logits = model(input_ids=input_ids,position_ids=position_ids,token_type_ids=token_type_ids)
                    lm_logits= logits[0]
            
                    loss = loss_function(lm_logits.view(-1,lm_logits.size(-1)),label_ids.view(-1))
                    running_loss += loss.item()
                    pbar.set_description('Train (Epoch{}):{:.4f}'.format(epoch,running_loss/(step+1)))
                    optimizer.zero_grad() # dw = 0
                    loss.backward()
                    optimizer.step() # w = w +dw
                    step += 1
                epoch += 1
        except KeyboardInterrupt:
            pbar.close()
            raise
        pbar.close()
    torch.save({'model':model.state_dict(),
               'epoch':epoch})

# %%
run(model,loader,1e-4,10)
# Out:
#   0%|                                                                                         | 0/2000 [00:00<?, ?it/s]
#   0%|                                                                                         | 0/2000 [00:00<?, ?it/s]
# Train (Epoch0):3.3523:   2%|█▎                                                     | 46/2000 [03:49<3:32:58,  6.54s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-eae72768be66> in <module>
# ----> 1 run(model,loader,1e-4,10)
#
# <ipython-input-24-4ddb0faaffb1> in run(model, train_dataloader, learning_rate, epoches)
#      21                     optimizer.zero_grad() # dw = 0
#      22                     loss.backward()
# ---> 23                     optimizer.step() # w = w +dw
#      24                     step += 1
#      25                 epoch += 1
#
# D:\Anaconda\Installed\lib\site-packages\torch\optim\adam.py in step(self, closure)
#     105                 step_size = group['lr'] * math.sqrt(bias_correction2) / bias_correction1
#     106
# --> 107                 p.data.addcdiv_(-step_size, exp_avg, denom)
#     108
#     109         return loss
#
# KeyboardInterrupt:

# %% [markdown]
# transformers  -- > pretrained-bert-...
